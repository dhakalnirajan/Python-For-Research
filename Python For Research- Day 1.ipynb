# %% [markdown]
# Classwork:
# Displaying my name.

# %%
print('Hi! I am Nirajan.')
# Out:
# Hi! I am Nirajan.

# %%
a = 10
b = 5

c = a-b
print(c)
# Out:
# 5

# %%
num1 = 56
num2 = 87

# %%
tmp = num1

# %%
num1 = num2

# %%
num1
# Out:
# 87

# %%
num2 = tmp

# %%
print(num1)
print(num2)
# Out:
# 87
# 56

# %%
# swap the values from the variable
num1 = 70
num2 = 60
# expected ouptut is num1 = 60 and num2 = 70

# %%
a = 5
b = 6
a, b = 5, 6    # assigning multiple values in multiple variables in same line

# %%
print("Before Swap num1 = {} , num22 = {}".format(num1, num2))
num1 = num1 + num2        # num1 = 130, num1 + num2 = 70+60
num2 = num2 + num1

# %%
5%2
# Out:
# 1
