# %% [markdown]
# # Python Numbers

# %%
a = 8
b = 0.9
c = 2 - 0.5j

# %%
# type checking in python
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
isinstance(a, int)
# Out:
# True

# %%
# True, False -- bool in python

# %% [markdown]
# Taking Input From the User

# %%
num1 = input('Enter first number : ')
num2 = input('Enter second number : ')
total = num1 + num2
print(total)
# Out:
# Enter first number : 69
# Enter second number : 9
# 699

# %%
num1 = int(input('Enter first number : '))
num2 = int(input('Enter second number : '))
total = num1 + num2
print("The Sum of {} and {} is {}".format(num1, num2, total))
# Out:
# Enter first number : 343
# Enter second number : 737
# The Sum of 343 and 737 is 1080

# %% [markdown]
# # **Conditionals in Python With number data types**

# %%
user_input = int(input("Enter a number : "))

# %%
rem = user_input % 2
print(rem)
# Out:
# 1

# %%
# Applying Conditions
if rem == 0:
  print("The Number is even")
else:
  print("The number is odd")
# Out:
# The number is odd

# %%
# == compares values of two object -- comparison operator

# %% [markdown]
# # **Comparison Conditions**

# %%
1 < 2
6 > 3
2 == 2
2<= 2
2 >= 2
5 <= 2
# Out:
# False

# %% [markdown]
# # Task

# %%
# WAP to take input from the user and check if the input number is positive, negative or zero.
a = int(input("Enter a number : "))
if a > 0:
    print("The Number is positive.")
elif a < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number : 0
# The number is 0.

# %%
# Nesting of Conditionals
user_input = int(input("Enter a number : "))
if user_input == 0:
    print("zero")
elif user_input < 0:
    print("negative")
else:
    print("positive")
# Out:
# Enter a number : 0
# zero

# %% [markdown]
# ## Assignment: Calculating BMI using If-Else conditionals

# %% [markdown]
# # Calculating BMI as Classwork

# %%
w = int(input("Weight = "))
h = int(input("Height = "))
h_m = h / 100


BMI = w / (h_m ** 2)

if BMI < 18.5:
    print("underweight")
elif BMI >= 18.5 and BMI <= 24.9:
    print("Normal Weight")
elif BMI >= 25 and BMI <= 29.9:
    print("Overweight")
elif BMI == 30 and BMI > 30:
    print("Obesity")
# Out:
# Weight = 60
# Height = 178
# Normal Weight
