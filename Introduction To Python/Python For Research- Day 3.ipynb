# %% [markdown]
# # String Datatype in Python

# %%
a = 'Hello World'

# %%
type(a)
# Out:
# str

# %% [markdown]
# # Multiple strings in Python

# %%
txt = "Hi! I am Nirajan. "
txt1 = "Hi! We are in Day-3"

# %%
print(txt, txt1)
# Out:
# Hi! I am Nirajan.  Hi! We are in Day-3

# %% [markdown]
# # indexing in Strings in python

# %%
txt = 'Hello World'
txt[10]
# Out:
# 'd'

# %% [markdown]
# # For Loop in Strings

# %%
for index in range(0, len(txt), 1):
    letter = txt[index]
    print("Index: {} has {} letter".format)

# %%
# Classwork: Print string 'Hello World' backwards
s = 'Hello world'

# %%
s[10]
# Out:
# 'd'

# %%
start = len(s) - 1
end = -1
step = -1

# %%
for index in range(start, end, step):
    letter = s[index]
    print(letter)
# Out:
# d
# l
# r
# o
# w
#
# o
# l
# l
# e
# H

# %%
# Classwork: WAP to print vowel and consonants from given string
s = 'aeyi'
start = 0
end = len(s)
step = 1

for index in range(start, end, step):
    letter = s[index]

    if letter == 'a' or letter == 'e' or letter == 'i' or letter == 'o' or letter == 'u':
        print("The letter {} is vowel".format(letter))
    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter a is vowel
# The letter e is vowel
# The letter y is consonant
# The letter i is vowel

# %% [markdown]
# ## Assignment: WAP to count vowel and consonant in the given string

# %%
# Classwork: WAP to print vowel and consonants from given string
s = 'Hi My name is Nirajan'
start = 0
end = len(s)
step = 1

for index in range(start, end, step):
    letter = s[index]

    if letter == 'a' or letter == 'e' or letter == 'i' or letter == 'o' or letter == 'u':
        print("The letter {} is vowel".format(letter))
    elif letter == " ":
        continue       # continue or break. Continue continues the loop while skipping space and break breaks the loop when it finds the space in this code.
    else:
        print("The letter {} is consonant".format(letter))
# Out:
# The letter H is consonant
# The letter i is vowel
# The letter M is consonant
# The letter y is consonant
# The letter n is consonant
# The letter a is vowel
# The letter m is consonant
# The letter e is vowel
# The letter i is vowel
# The letter s is consonant
# The letter N is consonant
# The letter i is vowel
# The letter r is consonant
# The letter a is vowel
# The letter j is consonant
# The letter a is vowel
# The letter n is consonant

# %% [markdown]
# Slicing in Python

# %%
s = "Hi My Name is Nirajan"

# %%
s[0]
# Out:
# 'H'

# %%
s[0:]
# Out:
# 'Hi My Name is Nirajan'

# %%
s[:6]     # slices and gives string from 0 to 7
# Out:
# 'Hi My '

# %%
s[0:7]   # slices and gives string from 0 to 7
# Out:
# 'Hi My N'

# %%
name = 'N!rajan'

# %%
name[1]
# Out:
# '!'

# %%
name[1] = !     # Immutable datatype
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-ec8bcc34561c> in <module>
# ----> 1 name[1] = get_ipython().getoutput('     # Immutable datatype')
#
# TypeError: 'str' object does not support item assignment

# %%
name = 'N!rajan   !!'
name.replace('!', 'i')
# Out:
# 'Nirajan   ii'

# %%
"Happy Dashain".replace("Happy", "Replace")
# Out:
# 'Replace Dashain'

# %% [markdown]
# ## Changing case. (Text normalization in NLPs)

# %%
txt = "happy dashain"

# %%
txt.upper()
# Out:
# 'HAPPY DASHAIN'

# %%
txt.lower()
# Out:
# 'happy dashain'

# %%
text = "This will split all words"

# %%
text.split()
# Out:
# ['This', 'will', 'split', 'all', 'words']

# %%
type(text.split())
# Out:
# list

# %% [markdown]
# # Python List

# %%
text = "This will split all words"
words = text.split()

# %%
last_index = len(words) -1
words
# Out:
# ['This', 'will', 'split', 'all', 'words']

# %%
words[0]
# Out:
# 'This'

# %%
for i in range(len(words)):
    letter = words[0]
    print(letter)
# Out:
# This
# This
# This
# This
# This
